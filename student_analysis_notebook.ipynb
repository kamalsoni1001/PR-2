# %% [markdown]
# # Student Performance Analysis
# This notebook demonstrates Descriptive, Diagnostic, Predictive, and Prescriptive analytics.

# %%
import pandas as pd
df = pd.read_csv('student_performance.csv')
df.head()

# %% [markdown]
# ## Descriptive Analysis

# %%
df.describe()

# %% [markdown]
# ## Diagnostic Analysis

# %%
df.groupby('Grade').mean()

# %% [markdown]
# ## Predictive Analysis

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = df[['Study_Hours','Attendance_%','Previous_Score','Participation']]
y = df['Final_Score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model = LinearRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)

# %% [markdown]
# ## Prescriptive Analysis

# %%
# Suggest improvement
df['Recommended_Study_Hours'] = df['Study_Hours'] + 2
df[['Student_ID','Study_Hours','Recommended_Study_Hours']].head()
